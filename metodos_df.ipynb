# %%
import pandas as pd

# %% [markdown]
# Inspeccion de datos

# %%
list_columns = ["Raza","Color","Peso"]
list_data = [
    ["Pincher" , "caramelo" , 6],
    ["Doberman", "Negro" , 20],
    ["Chow chow", "Cafe" , 10],
    ["Golden Retriver", "Cafe" , 12],
    
]
df_mascotas = pd.DataFrame(data=list_data , columns=list_columns)
display(df_mascotas)
# Out:
#               Raza     Color  Peso
# 0          Pincher  caramelo     6
# 1         Doberman     Negro    20
# 2        Chow chow      Cafe    10
# 3  Golden Retriver      Cafe    12

# %% [markdown]
# Metodo  head

# %%
display(df_mascotas.head(2))
# Out:
#        Raza     Color  Peso
# 0   Pincher  caramelo     6
# 1  Doberman     Negro    20

# %% [markdown]
# Método info

# %%
display(df_mascotas.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Raza    4 non-null      object
#  1   Color   4 non-null      object
#  2   Peso    4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
# None

# %% [markdown]
# Método describe

# %%
display(df_mascotas["Raza"].describe())
# Out:
# count           4
# unique          4
# top       Pincher
# freq            1
# Name: Raza, dtype: object

# %% [markdown]
# Método shape

# %%
display(df_mascotas.shape)
# Out:
# (4, 3)

# %% [markdown]
# Selección y filtrado

# %%
conteo = df_mascotas[["Raza", "Color"]]
display(conteo)
# Out:
#               Raza     Color
# 0          Pincher  caramelo
# 1         Doberman     Negro
# 2        Chow chow      Cafe
# 3  Golden Retriver      Cafe

# %% [markdown]
# Indices

# %%
list_inices = ["Raza","Color","Peso"]
list_columns = ["Raza","Color","Peso"]
list_data = [
    ["Pincher" , "caramelo" , 6],
    ["Doberman", "Negro" , 20],
    ["Chow chow", "Cafe" , 10],
    ["Golden Retriver", "Cafe" , 12],
    
]
df_mascotas = pd.DataFrame(data=list_data , columns=list_columns)
display(df_mascotas)
# Out:
#               Raza     Color  Peso
# 0          Pincher  caramelo     6
# 1         Doberman     Negro    20
# 2        Chow chow      Cafe    10
# 3  Golden Retriver      Cafe    12

# %%
print(df_mascotas.loc["Raza"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(df_mascotas.loc["Raza"])
#
# File c:\Users\USUARIO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\USUARIO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# ...
